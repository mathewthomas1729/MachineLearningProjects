# %%
import pandas as pd
import numpy as np
df = pd.read_csv('data/train.csv', index_col=None)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
# C:\Users\Matt\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000         NaN    0.000000
# 50%     446.000000    0.000000    3.000000         NaN    0.000000
# 75%     668.500000    1.000000    3.000000         NaN    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# ...

# %%
df.describe(include=['O'])
# Out:
#                                 Name   Sex    Ticket    Cabin Embarked
# count                            891   891       891      204      889
# unique                           891     2       681      147        3
# top     Theobald, Mr. Thomas Leonard  male  CA. 2343  B96 B98        S
# freq                               1   577         7        4      644

# %%
#Age is missing. so we can apply median of sex and class to the missing values of age.
df1=df[['Age','Pclass','Sex']].dropna()

((df1[(df1.Sex=='female') & (df1.Pclass == 1)]))['Age']
np.median(((df1[(df1.Sex=='female') & (df1.Pclass == 1)]))['Age'])
# Out:
# 35.0

# %%
print("Median of Females in 1st class is " + 
      str(np.median(df_1[(df_1.Pclass==1) & (df_1.Sex=='female')]['Age'])))
print("Median of Females in 2nd class is " + 
      str(np.median(df_1[(df_1.Pclass==2) & (df_1.Sex=='female')]['Age'])))
print("Median of Females in 3rd class is " + 
      str(np.median(df_1[(df_1.Pclass==3) & (df_1.Sex=='female')]['Age'])))
print("Median of Males in 1st class is " + 
      str(np.median(df_1[(df_1.Pclass==1) & (df_1.Sex=='male')]['Age'])))
print("Median of Males in 2nd class is " + 
      str(np.median(df_1[(df_1.Pclass==2) & (df_1.Sex=='male')]['Age'])))
print("Median of Males in 3rd class is " + 
      str(np.median(df_1[(df_1.Pclass==3) & (df_1.Sex=='male')]['Age'])))
# Out:
# 35.0
# 28.0
# 21.5
# 40.0
# 30.0
# 25.0

# %%
data1 = df[(df.Sex=='female') & (df.Pclass == 1)]
data1['Age'] = data1['Age'].fillna(35.0)
data2 = df[(df.Sex=='female') & (df.Pclass == 2)]
data2['Age'] = data2['Age'].fillna(28.0)
data3 = df[(df.Sex=='female') & (df.Pclass == 3)]
data3['Age'] = data3['Age'].fillna(21.5)
data4 = df[(df.Sex=='male') & (df.Pclass == 1)]
data4['Age'] = data4['Age'].fillna(40.0)
data5 = df[(df.Sex=='male') & (df.Pclass == 2)]
data5['Age'] = data5['Age'].fillna(30.0)
data6 = df[(df.Sex=='male') & (df.Pclass == 3)]
data6['Age'] = data6['Age'].fillna(25.0)
final_data = pd.concat([data1,data2,data3,data4,data5,data6])
final_data.describe()
# Out:
# C:\Users\Matt\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\Matt\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Matt\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
final_data.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 11           12         1       1
# 31           32         1       1
# 52           53         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 31     Spencer, Mrs. William Augustus (Marie Eugenie)  female  35.0      1
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
#
#     Parch    Ticket      Fare Cabin Embarked
# 1       0  PC 17599   71.2833   C85        C
# 3       0    113803   53.1000  C123        S
# 11      0    113783   26.5500  C103        S
# 31      0  PC 17569  146.5208   B78        C
# 52      0  PC 17572   76.7292   D33        C

# %%
final_data['Survived'].value_counts(normalize=True)
# Out:
# 0    0.616162
# 1    0.383838
# Name: Survived, dtype: float64

# %%
final_data[final_data.Sex=='female'].Survived.value_counts(normalize=True)
# Out:
# 1    0.742038
# 0    0.257962
# Name: Survived, dtype: float64

# %%
final_data[final_data.Sex=='male'].Survived.value_counts(normalize=True)
# Out:
# 0    0.811092
# 1    0.188908
# Name: Survived, dtype: float64

# %% [markdown]
# 18 percent of the males survived whereas 25 percent of females survived the titanic.

# %%
final_data[final_data.Pclass==1].Survived.value_counts(normalize=True)
# Out:
# 1    0.62963
# 0    0.37037
# Name: Survived, dtype: float64

# %%
final_data[final_data.Pclass==2].Survived.value_counts(normalize=True)
# Out:
# 0    0.527174
# 1    0.472826
# Name: Survived, dtype: float64

# %%
final_data[final_data.Pclass==3].Survived.value_counts(normalize=True)
# Out:
# 0    0.757637
# 1    0.242363
# Name: Survived, dtype: float64

# %% [markdown]
# 62 percent of class 1 survived and only 24 percent of class 3

# %%
final_data['SibSp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
#dividing into 5 quantiles and seeing distribution
pd.qcut(final_data['Age'],5).value_counts()
# Out:
# (20, 25]      258
# (30, 40]      185
# [0.42, 20]    179
# (40, 80]      150
# (25, 30]      119
# Name: Age, dtype: int64

# %%
final_data['Survived'].groupby(pd.qcut(final_data['Age'], 5)).mean()
# Out:
# Age
# [0.42, 20]    0.458101
# (20, 25]      0.294574
# (25, 30]      0.386555
# (30, 40]      0.448649
# (40, 80]      0.366667
# Name: Survived, dtype: float64

# %%
pd.qcut(final_data['Fare'],4).value_counts()
# Out:
# (7.91, 14.454]    224
# [0, 7.91]         223
# (31, 512.329]     222
# (14.454, 31]      222
# Name: Fare, dtype: int64

# %%
final_data['Survived'].groupby(pd.qcut(final_data['Fare'], 4)).mean()
# Out:
# Fare
# [0, 7.91]         0.197309
# (7.91, 14.454]    0.303571
# (14.454, 31]      0.454955
# (31, 512.329]     0.581081
# Name: Survived, dtype: float64

# %%
#you can see higher the fare the higher the chances of survival

# %%
final_data['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
final_data[final_data.Embarked=='S'].Survived.value_counts(normalize=True)
# Out:
# 0    0.663043
# 1    0.336957
# Name: Survived, dtype: float64

# %%
final_data[final_data.Embarked=='C'].Survived.value_counts(normalize=True)
# Out:
# 1    0.553571
# 0    0.446429
# Name: Survived, dtype: float64

# %%
final_data[final_data.Embarked=='Q'].Survived.value_counts(normalize=True)
# Out:
# 0    0.61039
# 1    0.38961
# Name: Survived, dtype: float64

# %%
final_data.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 11           12         1       1
# 31           32         1       1
# 52           53         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 31     Spencer, Mrs. William Augustus (Marie Eugenie)  female  35.0      1
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
#
#     Parch    Ticket      Fare Cabin Embarked
# 1       0  PC 17599   71.2833   C85        C
# 3       0    113803   53.1000  C123        S
# 11      0    113783   26.5500  C103        S
# 31      0  PC 17569  146.5208   B78        C
# 52      0  PC 17572   76.7292   D33        C

# %%
def ticket_grouped(train):
    for i in [train]:
        i['Ticket_Lett'] = i['Ticket'].apply(lambda x: str(x)[0])
        i['Ticket_Lett'] = i['Ticket_Lett'].apply(lambda x: str(x))
        i['Ticket_Lett'] = np.where((i['Ticket_Lett']).isin(['1', '2', '3', 'S', 'P', 'C', 'A']), i['Ticket_Lett'],
                                   np.where((i['Ticket_Lett']).isin(['W', '4', '7', '6', 'L', '5', '8']),
                                            'Low_ticket', 'Other_ticket'))
        i['Ticket_Len'] = i['Ticket'].apply(lambda x: len(x))
        del i['Ticket']
    return train

# %%
final_data = ticket_grouped(final_data)

# %%
final_data.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 11           12         1       1
# 31           32         1       1
# 52           53         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 31     Spencer, Mrs. William Augustus (Marie Eugenie)  female  35.0      1
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
#
#     Parch      Fare Cabin Embarked Ticket_Lett  Ticket_Len
# 1       0   71.2833   C85        C           P           8
# 3       0   53.1000  C123        S           1           6
# 11      0   26.5500  C103        S           1           6
# 31      0  146.5208   B78        C           P           8
# ...

# %%
final_data['Ticket_Lett'].value_counts()
# Out:
# 3               301
# 2               183
# 1               146
# S                65
# P                65
# C                47
# Low_ticket       47
# A                29
# Other_ticket      8
# Name: Ticket_Lett, dtype: int64

# %%
final_data['Ticket_Len'].value_counts()
# Out:
# 6     419
# 5     131
# 4     101
# 8      76
# 10     41
# 7      27
# 9      26
# 17     14
# 16     11
# 13     10
# 12     10
# 15      9
# 11      8
# 18      6
# 3       2
# Name: Ticket_Len, dtype: int64

# %%
#family size based on sibsp+parch
def fam_size(train):
    for i in [train]:
        i['Fam_Size'] = np.where((i['SibSp']+i['Parch']) == 0 , 'Solo',
                           np.where((i['SibSp']+i['Parch']) <= 3,'Nuclear', 'Big'))
        del i['SibSp']
        del i['Parch']
    return train

# %%
final_data=fam_size(final_data)

# %%
final_data['Fam_Size'].value_counts()
# Out:
# Solo       537
# Nuclear    292
# Big         62
# Name: Fam_Size, dtype: int64

# %%
final_data[final_data.Fam_Size=='Solo'].Survived.value_counts(normalize=True)
# Out:
# 0    0.696462
# 1    0.303538
# Name: Survived, dtype: float64

# %%
final_data[final_data.Fam_Size=='Nuclear'].Survived.value_counts(normalize=True)
# Out:
# 1    0.578767
# 0    0.421233
# Name: Survived, dtype: float64

# %%
final_data[final_data.Fam_Size=='Big'].Survived.value_counts(normalize=True)
# Out:
# 0    0.83871
# 1    0.16129
# Name: Survived, dtype: float64

# %%
final_data['Name_Title'] = final_data['Name'].apply(lambda x: x.split(',')[1]).apply(lambda x: x.split()[0])

# %%
final_data['Name_Title'].value_counts()
# Out:
# Mr.          517
# Miss.        182
# Mrs.         125
# Master.       40
# Dr.            7
# Rev.           6
# Col.           2
# Major.         2
# Mlle.          2
# the            1
# Capt.          1
# Don.           1
# Lady.          1
# Ms.            1
# Jonkheer.      1
# Sir.           1
# Mme.           1
# Name: Name_Title, dtype: int64

# %%
def get_title(train):
    for i in [train]:
        i['Title'] = train['Name'].apply(lambda x:x.split(',')[1]).apply(lambda x:x.split()[0])
    return train

# %%
final_data = get_title(final_data)

# %%
final_data['Title'].value_counts()
# Out:
# Mr.          517
# Miss.        182
# Mrs.         125
# Master.       40
# Dr.            7
# Rev.           6
# Col.           2
# Major.         2
# Mlle.          2
# the            1
# Capt.          1
# Don.           1
# Lady.          1
# Ms.            1
# Jonkheer.      1
# Sir.           1
# Mme.           1
# Name: Title, dtype: int64

# %%
#split()[-1] -- returns all splits
#lambda x is i same as f(x): return str(x).split()[-1]
final_data['Cabin_num'] = final_data['Cabin'].apply(lambda x: str(x).split()[-1][1:])

# %%
s = "Hello world! How are you?"  
t= s.split()[-1]
#-1 returns the last split
t[1:]
#1: returns the the string from index 1
# Out:
# 'ou?'

# %%
final_data
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 31            32         1       1
# 52            53         1       1
# 61            62         1       1
# 88            89         1       1
# 136          137         1       1
# 151          152         1       1
# 166          167         1       1
# 177          178         0       1
# 194          195         1       1
# 195          196         1       1
# 215          216         1       1
# 218          219         1       1
# 230          231         1       1
# 256          257         1       1
# 257          258         1       1
# 258          259         1       1
# 268          269         1       1
# 269          270         1       1
# 275          276         1       1
# 290          291         1       1
# 291          292         1       1
# 297          298         0       1
# ...
