# %%
#importing relevant libraries
import numpy as np 
import pandas as pd 
from sklearn import feature_extraction, linear_model, model_selection, preprocessing
import nltk
from nltk.tokenize import sent_tokenize,word_tokenize
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import stopwords

# %%
#importing data into dataframes
train_df = pd.read_csv("data/train.csv")
test_df = pd.read_csv("data/test.csv")
train_df.describe(include='all')
# Out:
#                   id     keyword location  \
# count    7613.000000        7552     5080
# unique           NaN         221     3341
# top              NaN  fatalities      USA
# freq             NaN          45      104
# mean     5441.934848         NaN      NaN
# std      3137.116090         NaN      NaN
# min         1.000000         NaN      NaN
# 25%      2734.000000         NaN      NaN
# 50%      5408.000000         NaN      NaN
# 75%      8146.000000         NaN      NaN
# max     10873.000000         NaN      NaN
#
#                                                      text      target
# count                                                7613  7613.00000
# unique                                               7503         NaN
# top     11-Year-Old Boy Charged With Manslaughter of T...         NaN
# freq                                                   10         NaN
# mean                                                  NaN     0.42966
# std                                                   NaN     0.49506
# min                                                   NaN     0.00000
# 25%                                                   NaN     0.00000
# 50%                                                   NaN     0.00000
# 75%                                                   NaN     1.00000
# max                                                   NaN     1.00000

# %% [markdown]
# 61 missing keywords and 2533 missing locations

# %% [markdown]
# ## Steps in Model
#     1.remove urls
#     2.remove emojis
#     3.remove contractions
#     4.remove punctuations
#     5.tokenize and lemmatize
#     6.Vectorize dataset to feed into model
#     7.train model and evaluate model accuracy
#     8.generate submission file

# %%
#1. remove urls
import re
def remove_URL(text):
    urls = re.compile(r'https?://\S+|www\.\S+')
    text_without_https =  urls.sub(r'',text)
    url = re.compile(r'http?://\S+|www\.\S+')
    return url.sub(r'',text_without_https)
train_df['text']=train_df['text'].apply(remove_URL)
test_df['text']=test_df['text'].apply(remove_URL)

# %%
#2. remove emojis
def remove_emoji(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)
train_df['text']=train_df['text'].apply(remove_emoji)
test_df['text']=test_df['text'].apply(remove_emoji)

# %%
#3. remove contractions
contractions = { 
"ain't": "am not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he's": "he is",
"how'd": "how did",
"how'll": "how will",
"how's": "how is",
"i'd": "i would",
"i'll": "i will",
"i'm": "i am",
"i've": "i have",
"isn't": "is not",
"it'd": "it would",
"it'll": "it will",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"must've": "must have",
"mustn't": "must not",
"needn't": "need not",
"oughtn't": "ought not",
"shan't": "shall not",
"sha'n't": "shall not",
"she'd": "she would",
"she'll": "she will",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"that'd": "that would",
"that's": "that is",
"there'd": "there had",
"there's": "there is",
"they'd": "they would",
"they'll": "they will",
"they're": "they are",
"they've": "they have",
"wasn't": "was not",
"we'd": "we would",
"we'll": "we will",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"where'd": "where did",
"where's": "where is",
"who'll": "who will",
"who's": "who is",
"won't": "will not",
"wouldn't": "would not",
"you'd": "you would",
"you'll": "you will",
"you're": "you are",
"thx"   : "thanks"
}

def remove_contractions(text):
    temp = text.split()
    final_text =''
    for wrd in temp:
        if wrd.lower() in contractions:
            replaced_word = contractions[wrd.lower()] + ' '
        else:
            replaced_word = wrd + ' '
        final_text  = final_text + replaced_word
    return final_text.strip()

train_df['text']=train_df['text'].apply(remove_contractions)
test_df['text']=test_df['text'].apply(remove_contractions)

# %%
#4. remove punctuation
import string
def remove_punct(text):
    table=str.maketrans('','',string.punctuation)
    return text.translate(table)
train_df['text']=train_df['text'].apply(remove_punct)
test_df['text']=test_df['text'].apply(remove_punct)

# %%
#5. tokenize and lemmatize
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# %%
def tokenize_and_lemmatize(text):    
    text_tokens = word_tokenize(text.lower())
    tokens_without_sw = [word for word in text_tokens if not word in stopwords.words()]
    word_list = [lemmatizer.lemmatize(w) for w in tokens_without_sw]
    return word_list
train_df['text_tokens']=train_df['text'].apply(tokenize_and_lemmatize)
test_df['text_tokens']=test_df['text'].apply(tokenize_and_lemmatize)

# %%
#reconstruct clean sentence from tokens
def reconstruct_sentence(tokens):
    sentence = ''
    for i in tokens:
        sentence = sentence + ' ' + i
    return sentence.strip()
train_df['clean_text']= train_df['text_tokens'].apply(reconstruct_sentence)
test_df['clean_text']= test_df['text_tokens'].apply(reconstruct_sentence)
#checking first few records
train_df.head(5)
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this earthquake Ma...
# 1   4     NaN      NaN              Forest fire near La Ronge Sask Canada
# 2   5     NaN      NaN  All residents asked to shelter in place are be...
# 3   6     NaN      NaN  13000 people receive wildfires evacuation orde...
# 4   7     NaN      NaN  Just got sent this photo from Ruby Alaska as s...
#
#    target                                        text_tokens  \
# 0       1  [deed, reason, earthquake, may, allah, forgive...
# 1       1          [forest, fire, near, ronge, sask, canada]
# 2       1  [resident, asked, shelter, place, notified, of...
# 3       1  [13000, people, receive, wildfire, evacuation,...
# 4       1  [got, sent, photo, ruby, alaska, smoke, wildfi...
#
#                                           clean_text
# 0         deed reason earthquake may allah forgive u
# 1                 forest fire near ronge sask canada
# 2  resident asked shelter place notified officer ...
# 3  13000 people receive wildfire evacuation order...
# 4  got sent photo ruby alaska smoke wildfire pour...

# %%
#6. converting data into TFID vectors and also using bigrams as they add more context when words are combined
tfid_vectorizer = feature_extraction.text.TfidfVectorizer(ngram_range=(1,2))
train_vectors_tfid = tfid_vectorizer.fit_transform(train_df["clean_text"])
test_vectors_tfid = tfid_vectorizer.transform(test_df["clean_text"])

# %%
#7. Training model using RgidgeClassifier
clf = linear_model.RidgeClassifier()
scores = model_selection.cross_val_score(clf, train_vectors_tfid, train_df["target"], cv=5, scoring="f1")
print("average score of model is {}".format(np.mean(scores)))
# Out:
# average score of model is 0.5484058791442074

# %%
clf.fit(train_vectors_tfid, train_df["target"])
pred=clf.predict(test_vectors_tfid)
print(tfid_vectorizer.vocabulary_)
# Out:
# {'deed': 15080, 'reason': 44113, 'earthquake': 17616, 'may': 34602, 'allah': 3122, 'forgive': 21974, 'deed reason': 15081, 'reason earthquake': 44121, 'earthquake may': 17631, 'may allah': 34604, 'allah forgive': 3124, 'forest': 21927, 'fire': 20926, 'near': 37229, 'ronge': 45941, 'sask': 46876, 'canada': 9772, 'forest fire': 21930, 'fire near': 21040, 'near ronge': 37261, 'ronge sask': 45942, 'sask canada': 46877, 'resident': 45015, 'asked': 4927, 'shelter': 48535, 'place': 41300, 'notified': 38343, 'officer': 38856, 'evacuation': 18943, 'order': 39477, 'expected': 19452, 'resident asked': 45016, 'asked shelter': 4934, 'shelter place': 48539, 'place notified': 41319, 'notified officer': 38344, 'officer evacuation': 38859, 'evacuation shelter': 18971, 'place order': 41320, 'order expected': 39488, '13000': 392, 'people': 40569, 'receive': 44173, 'wildfire': 59539, 'california': 9522, '13000 people': 394, 'people receive': 40667, 'receive wildfire': 44175, 'wildfire evacuation': 59552, 'evacuation order': 18966, 'order california': 39481, 'got': 24208, 'sent': 48016, 'photo': 40999, 'ruby': 46268, 'alaska': 2998, 'smoke': 49754, 'pours': 42154, 'school': 47260, 'got sent': 24294, 'sent photo': 48024, 'photo ruby': 41032, 'ruby alaska': 46269, 'alaska smoke': 3002, 'smoke wildfire': 49796, 'wildfire pours': 59572, 'pours school': 42155, 'rockyfire': 45839, 'update': 56902, 'hwy': 27513, '20': 706, 'closed': 11709, 'direction': 16138, 'due': 17379, 'lake': 31012, 'county': 13217, 'cafire': 9420, 'rockyfire update': 45842, 'update california': 56908, 'california hwy': 9549, 'hwy 20': 27514, '20 closed': 711, 'closed direction': 11714, 'direction due': 16140, 'due lake': 17390, 'lake county': 31014, 'county fire': 13230, 'fire cafire': 20957, 'cafire wildfire': 9421, 'flood': 21498, 'disaster': 16199, 'heavy': 25955, 'rain': 43543, 'cause': 10374, 'flash': 21381, 'flooding': 21572, 'street': 51743, 'manitou': 34141, 'colorado': 12212, 'spring': 50759, 'area': 4473, 'flood disaster': 21516, 'disaster heavy': 16227, 'heavy rain': 25962, 'rain cause': 43549, 'cause flash': 10391, 'flash flooding': 21385, 'flooding street': 21603, 'street manitou': 51756, 'manitou colorado': 34142, 'colorado spring': 12218, 'spring area': 50761, 'top': 55045, 'hill': 26419, 'see': 47662, 'wood': 60053, 'top hill': 55061, 'hill see': 26430, 'see fire': 47688, 'fire wood': 21119, 'emergency': 18147, 'happening': 25382, 'building': 8934, 'across': 2307, 'emergency evacuation': 18167, 'evacuation happening': 18958, 'happening building': 25383, 'building across': 8939, 'across street': 2321, 'afraid': 2643, 'tornado': 55101, 'coming': 12291, 'afraid tornado': 2647, 'tornado coming': 55105, 'coming area': 12294, 'three': 54236, 'died': 16027, 'heat': 25926, 'wave': 58669, 'far': 20126, 'three people': 54250, 'people died': 40596, 'died heat': 16034, 'heat wave': 25940, 'wave far': 58679, 'haha': 25085, 'south': 50399, 'tampa': 53010, 'getting': 23380, 'flooded': 21567, 'hah': 25082, 'wait': 58165, 'second': 47584, 'live': 32725, 'gon': 24022, 'fvck': 22778, 'haha south': 25094, 'south tampa': 50418, 'tampa getting': 53012, 'getting flooded': 23400, 'flooded hah': 21569, 'hah wait': 25083, 'wait second': 58180, 'second live': 47597, 'live south': 32753, 'tampa gon': 53013, 'gon gon': 24040, 'gon fvck': 24037, 'fvck flooding': 22779, 'raining': 43598, 'florida': 21634, 'tampabay': 53015, '18': 553, '19': 597, 'day': 14600, 'lost': 33274, 'count': 13176, 'raining flooding': 43599, 'flooding florida': 21583, 'florida tampabay': 21641, 'tampabay tampa': 53016, 'tampa 18': 53011, '18 19': 554, '19 day': 600, 'day lost': 14657, 'lost count': 33281, 'bago': 5914, 'myanmar': 36908, 'arrived': 4718, 'flood bago': 21504, 'bago myanmar': 5915, 'myanmar arrived': 36909, 'arrived bago': 4720, 'damage': 14239, 'bus': 9220, '80': 1699, 'car': 9939, 'crash': 13420, 'breaking': 8469, 'damage school': 14276, 'school bus': 47266, 'bus 80': 9222, '80 car': 1701, 'car crash': 995 ...

# %%
#8. generating submission file  
sample_submission = pd.read_csv("sample_submission.csv")
sample_submission['target']=clf.predict(test_vectors_tfid)
sample_submission.to_csv('submission0403_bigram.csv',index=False)

# %% [markdown]
# ### Summary
# This was my first foray into natural language processing and this was a model that was pretty straight forward. I think it can be used as a good baseline to reference as I start using more advance machine learning algorithims and techniques.
# Using this I acheived a score of 0.80263
